# %% [markdown]
# # Minibatch K-means

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy
import sklearn

# Normalizador de información mutua
from sklearn.metrics import normalized_mutual_info_score as NMI
# Normalizador
from sklearn.preprocessing import StandardScaler as SS
# Dimensionador
from sklearn.decomposition import PCA 
# Gestionador MiniBatchKMeans 
from sklearn.cluster import MiniBatchKMeans

# Parametros
CSV_PATH = 'prueba.csv'
CLUSTERS = 8
MAX_IT = 1000
BATCH_SIZE = 100
MAX_NI = 10

# Se obtienen los datos del archivo
dataset = pd.read_csv(CSV_PATH)

# Se filtra el dataset por valores numéricos sin contar brewery_time e identificadores
data = pd.DataFrame({'review_overall':    dataset['review_overall'],
                     'review_aroma':      dataset['review_aroma'],
                     'review_appearance': dataset['review_appearance'],
                     'review_palate':     dataset['review_palate'],
                     'review_taste':      dataset['review_taste'],
                     'beer_abv':          dataset['beer_abv']})

# Se arregla el dataset asumiendo 0 == vacio - Error: NaN found
data = data.fillna(0)

# Se normalizan los datos y se disminuye la dimención
data = SS().fit_transform(data)
data = PCA(n_components = 2).fit_transform(data)

# Inicialización de MiniBatch K-Means
mnk_means = MiniBatchKMeans(init='k-means++', n_clusters=CLUSTERS, n_init=MAX_IT, batch_size=BATCH_SIZE, max_no_improvement=MAX_NI)
mnk_means.fit(data)

# Asignación de labels
labels = mnk_means.labels_


for label in np.unique(labels):
    plt.plot(data[labels == label, 0], data[labels == label, 1], '.')

plt.title('Clustering Mini Batch K-Means de ' + str(CLUSTERS))
plt.show()
# Out:
# Init 1/1000 with method: k-means++
# Inertia for init 1/1000: 205.136188
# Init 2/1000 with method: k-means++
# Inertia for init 2/1000: 231.169028
# Init 3/1000 with method: k-means++
# Inertia for init 3/1000: 216.332576
# Init 4/1000 with method: k-means++
# Inertia for init 4/1000: 224.736160
# Init 5/1000 with method: k-means++
# Inertia for init 5/1000: 225.717212
# Init 6/1000 with method: k-means++
# Inertia for init 6/1000: 216.326147
# Init 7/1000 with method: k-means++
# Inertia for init 7/1000: 216.445429
# Init 8/1000 with method: k-means++
# Inertia for init 8/1000: 245.721889
# Init 9/1000 with method: k-means++
# Inertia for init 9/1000: 220.147088
# Init 10/1000 with method: k-means++
# Inertia for init 10/1000: 209.182770
# Init 11/1000 with method: k-means++
# Inertia for init 11/1000: 204.152021
# Init 12/1000 with method: k-means++
# Inertia for init 12/1000: 227.081923
# Init 13/1000 with method: k-means++
# Inertia for init 13/1000: 222.750248
# Init 14/1000 with method: k-means++
# Inertia for init 14/1000: 224.160714
# Init 15/1000 with method: k-means++
# Inertia for init 15/1000: 206.839262
# Init 16/1000 with method: k-means++
# Inertia for init 16/1000: 240.185645
# Init 17/1000 with method: k-means++
# Inertia for init 17/1000: 215.726048
# Init 18/1000 with method: k-means++
# Inertia for init 18/1000: 256.166356
# Init 19/1000 with method: k-means++
# Inertia for init 19/1000: 229.932051
# Init 20/1000 with method: k-means++
# Inertia for init 20/1000: 215.891295
# Init 21/1000 with method: k-means++
# Inertia for init 21/1000: 250.195990
# Init 22/1000 with method: k-means++
# Inertia for init 22/1000: 219.698239
# Init 23/1000 with method: k-means++
# Inertia for init 23/1000: 238.877628
# Init 24/1000 with method: k-means++
# Inertia for init 24/1000: 244.140700
# Init 25/1000 with method: k-means++
# Inertia for init 25/1000: 229.068080
# Init 26/1000 with method: k-means++
# Inertia for init 26/1000: 216.658491
# Init 27/1000 with method: k-means++
# Inertia for init 27/1000: 245.671843
# Init 28/1000 with method: k-means++
# Inertia for init 28/1000: 230.669278
# Init 29/1000 with method: k-means++
# Inertia for init 29/1000: 252.508567
# Init 30/1000 with method: k-means++
# Inertia for init 30/1000: 219.832610
# Init 31/1000 with method: k-means++
# Inertia for init 31/1000: 235.193123
# Init 32/1000 with method: k-means++
# Inertia for init 32/1000: 229.713285
# Init 33/1000 with method: k-means++
# Inertia for init 33/1000: 211.749564
# Init 34/1000 with method: k-means++
# Inertia for init 34/1000: 225.277999
# Init 35/1000 with method: k-means++
# Inertia for init 35/1000: 219.071562
# Init 36/1000 with method: k-means++
# Inertia for init 36/1000: 237.892060
# Init 37/1000 with method: k-means++
# Inertia for init 37/1000: 254.971418
# Init 38/1000 with method: k-means++
# Inertia for init 38/1000: 231.510724
# Init 39/1000 with method: k-means++
# Inertia for init 39/1000: 243.136472
# Init 40/1000 with method: k-means++
# Inertia for init 40/1000: 214.076301
# Init 41/1000 with method: k-means++
# Inertia for init 41/1000: 257.772233
# Init 42/1000 with method: k-means++
# Inertia for init 42/1000: 252.496739
# Init 43/1000 with method: k-means++
# Inertia for init 43/1000: 211.717268
# Init 44/1000 with method: k-means++
# Inertia for init 44/1000: 233.628618
# Init 45/1000 with method: k-means++
# Inertia for init 45/1000: 230.395041
# Init 46/1000 with method: k-means++
# Inertia for init 46/1000: 215.745622
# Init 47/1000 with method: k-means++
# Inertia for init 47/1000: 228.246062
# Init 48/1000 with method: k-means++
# Inertia for init 48/1000: 214.466800
# Init 49/1000 with method: k-means++
# Inertia for init 49/1000: 227.624482
# Init 50/1000 with method: k-means++
# Inertia for init 50/1000: 233.974930
# Init 51/1000 with method: k-means++
# Inertia for init 51/1000: 204.668874
# Init 52/1000 with method: k-means++
# Inertia for init 52/1000: 238.722570
# Init 53/1000 with method: k-means++
# Inertia for init 53/1000: 226.956291
# Init 54/1000 with method: k-means++
# Inertia for init 54/1000: 219.632511
# Init 55/1000 with method: k-means++
# Inertia for init 55/1000: 238.030930
# Init 56/1000 with method: k-means++
# Inertia for init 56/1000: 231.858458
# Init 57/1000 with method: k-means++
# Inertia for init 57/1000: 233.977308
# Init 58/1000 with method: k-means++
# Inertia for init 58/1000: 208.677735
# Init 59/1000 with method: k-means++
# Inertia for init 59/1000: 241.478408
# Init 60/1000 with method: k-means++
# Inertia for init 60/1000: 229.303560
# Init 61/1000 with method: k-means++
# Inertia for init 61/1000: 234.757498
# Init 62/1000 with method: k-means++
# Inertia for init 62/1000: 221.408252
# Init 63/1000 with method: k-means++
# Inertia for init 63/1000: 231.367156
# Init 64/1000 with method: k-means++
# Inertia for init 64/1000: 222.878266
# Init 65/1000 with method: k-means++
# Inertia for init 65/1000: 203.072411
# Init 66/1000 with method: k-means++
# Inertia for init 66/1000: 225.111893
# Init 67/1000 with method: k-means++
# Inertia for init 67/1000: 240.674250
# Init 68/1000 with method: k-means++
# Inertia for init 68/1000: 215.692393
# Init 69/1000 with method: k-means++
# Inertia for init 69/1000: 218.799651
# Init 70/1000 with method: k-means++
# Inertia for init 70/1000: 255.174373
# Init 71/1000 with method: k-means++
# Inertia for init 71/1000: 254.144561
# Init 72/1000 with method: k-means++
# Inertia for init 72/1000: 230.455884
# Init 73/1000 with method: k-means++
# Inertia for init 73/1000: 212.460004
# Init 74/1000 with method: k-means++
# Inertia for init 74/1000: 262.195952
# Init 75/1000 with method: k-means++
# Inertia for init 75/1000: 242.446322
# Init 76/1000 with method: k-means++
# Inertia for init 76/1000: 222.132947
# Init 77/1000 with method: k-means++
# Inertia for init 77/1000: 224.250918
# Init 78/1000 with method: k-means++
# Inertia for init 78/1000: 247.994677
# Init 79/1000 with method: k-means++
# Inertia for init 79/1000: 233.640228
# Init 80/1000 with method: k-means++
# Inertia for init 80/1000: 223.558656
# Init 81/1000 with method: k-means++
# Inertia for init 81/1000: 230.727102
# Init 82/1000 with method: k-means++
# Inertia for init 82/1000: 210.402846
# Init 83/1000 with method: k-means++
# Inertia for init 83/1000: 256.152288
# Init 84/1000 with method: k-means++
# Inertia for init 84/1000: 226.976361
# Init 85/1000 with method: k-means++
# Inertia for init 85/1000: 241.274056
# Init 86/1000 with method: k-means++
# Inertia for init 86/1000: 222.266845
# Init 87/1000 with method: k-means++
# Inertia for init 87/1000: 239.068274
# Init 88/1000 with method: k-means++
# Inertia for init 88/1000: 243.538372
# Init 89/1000 with method: k-means++
# Inertia for init 89/1000: 209.049392
# Init 90/1000 with method: k-means++
# Inertia for init 90/1000: 244.470797
# Init 91/1000 with method: k-means++
# Inertia for init 91/1000: 230.070258
# Init 92/1000 with method: k-means++
# Inertia for init 92/1000: 253.765043
# Init 93/1000 with method: k-means++
# Inertia for init 93/1000: 245.231386
# Init 94/1000 with method: k-means++
# Inertia for init 94/1000: 310.477976
# Init 95/1000 with method: k-means++
# Inertia for init 95/1000: 214.040294
# Init 96/1000 with method: k-means++
# Inertia for init 96/1000: 225.129803
# Init 97/1000 with method: k-means++
# Inertia for init 97/1000: 252.610517
# Init 98/1000 with method: k-means++
# Inertia for init 98/1000: 241.077683
# Init 99/1000 with method: k-means++
# Inertia for init 99/1000: 222.597459
# Init 100/1000 with method: k-means++
# Inertia for init 100/1000: 234.684733
# Init 101/1000 with method: k-means++
# Inertia for init 101/1000: 233.415498
# Init 102/1000 with method: k-means++
# Inertia for init 102/1000: 252.568792
# Init 103/1000 with method: k-means++
# Inertia for init 103/1000: 204.277287
# Init 104/1000 with method: k-means++
# Inertia for init 104/1000: 242.784833
# Init 105/1000 with method: k-means++
# Inertia for init 105/1000: 235.023179
# Init 106/1000 with method: k-means++
# Inertia for init 106/1000: 215.977567
# Init 107/1000 with method: k-means++
# Inertia for init 107/1000: 200.870519
# Init 108/1000 with method: k-means++
# Inertia for init 108/1000: 224.839042
# Init 109/1000 with method: k-means++
# Inertia for init 109/1000: 222.433279
# Init 110/1000 with method: k-means++
# Inertia for init 110/1000: 228.919752
# Init 111/1000 with method: k-means++
# Inertia for init 111/1000: 209.779513
# Init 112/1000 with method: k-means++
# Inertia for init 112/1000: 228.863155
# Init 113/1000 with method: k-means++
# Inertia for init 113/1000: 220.178744
# Init 114/1000 with method: k-means++
# Inertia for init 114/1000: 221.487880
# Init 115/1000 with method: k-means++
# Inertia for init 115/1000: 233.265186
# Init 116/1000 with method: k-means++
# Inertia for init 116/1000: 248.594478
# Init 117/1000 with method: k-means++
# Inertia for init 117/1000: 215.294080
# Init 118/1000 with method: k-means++
# Inertia for init 118/1000: 256.596178
# Init 119/1000 with method: k-means++
# Inertia for init 119/1000: 201.369811
# Init 120/1000 with method: k-means++
# Inertia for init 120/1000: 222.956746
# Init 121/1000 with method: k-means++
# Inertia for init 121/1000: 252.911712
# Init 122/1000 with method: k-means++
# Inertia for init 122/1000: 231.058815
# Init 123/1000 with method: k-means++
# Inertia for init 123/1000: 220.150288
# Init 124/1000 with method: k-means++
# Inertia for init 124/1000: 238.001429
# Init 125/1000 with method: k-means++
# Inertia for init 125/1000: 217.495366
# Init 126/1000 with method: k-means++
# Inertia for init 126/1000: 218.947707
# Init 127/1000 with method: k-means++
# Inertia for init 127/1000: 242.002155
# Init 128/1000 with method: k-means++
# Inertia for init 128/1000: 271.403845
# Init 129/1000 with method: k-means++
# Inertia for init 129/1000: 212.219300
# Init 130/1000 with method: k-means++
# Inertia for init 130/1000: 234.489592
# Init 131/1000 with method: k-means++
# Inertia for init 131/1000: 217.364366
# Init 132/1000 with method: k-means++
# Inertia for init 132/1000: 201.789543
# Init 133/1000 with method: k-means++
# Inertia for init 133/1000: 237.927760
# Init 134/1000 with method: k-means++
# Inertia for init 134/1000: 225.371322
# Init 135/1000 with method: k-means++
# Inertia for init 135/1000: 224.470589
# Init 136/1000 with method: k-means++
# Inertia for init 136/1000: 262.003562
# Init 137/1000 with method: k-means++
# Inertia for init 137/1000: 238.138178
# Init 138/1000 with method: k-means++
# Inertia for init 138/1000: 212.769767
# Init 139/1000 with method: k-means++
# Inertia for init 139/1000: 223.321175
# Init 140/1000 with method: k-means++
# Inertia for init 140/1000: 218.849217
# Init 141/1000 with method: k-means++
# Inertia for init 141/1000: 247.825271
# Init 142/1000 with method: k-means++
# Inertia for init 142/1000: 204.210727
# Init 143/1000 with method: k-means++
# Inertia for init 143/1000: 235.170859
# Init 144/1000 with method: k-means++
# Inertia for init 144/1000: 232.264415
# Init 145/1000 with method: k-means++
# Inertia for init 145/1000: 216.807811
# Init 146/1000 with method: k-means++
# Inertia for init 146/1000: 236.001043
# Init 147/1000 with method: k-means++
# Inertia for init 147/1000: 228.488105
# Init 148/1000 with method: k-means++
# Inertia for init 148/1000: 223.680773
# Init 149/1000 with method: k-means++
# Inertia for init 149/1000: 253.877500
# Init 150/1000 with method: k-means++
# Inertia for init 150/1000: 229.983783
# Init 151/1000 with method: k-means++
# Inertia for init 151/1000: 236.707710
# Init 152/1000 with method: k-means++
# Inertia for init 152/1000: 242.788236
# Init 153/1000 with method: k-means++
# Inertia for init 153/1000: 233.453425
# Init 154/1000 with method: k-means++
# Inertia for init 154/1000: 238.272400
# Init 155/1000 with method: k-means++
# Inertia for init 155/1000: 249.798077
# Init 156/1000 with method: k-means++
# Inertia for init 156/1000: 232.083467
# Init 157/1000 with method: k-means++
# Inertia for init 157/1000: 225.680531
# Init 158/1000 with method: k-means++
# Inertia for init 158/1000: 236.835546
# Init 159/1000 with method: k-means++
# Inertia for init 159/1000: 222.603416
# Init 160/1000 with method: k-means++
# Inertia for init 160/1000: 217.921597
# Init 161/1000 with method: k-means++
# Inertia for init 161/1000: 237.106591
# Init 162/1000 with method: k-means++
# Inertia for init 162/1000: 233.639261
# Init 163/1000 with method: k-means++
# Inertia for init 163/1000: 220.848905
# Init 164/1000 with method: k-means++
# Inertia for init 164/1000: 236.880249
# Init 165/1000 with method: k-means++
# Inertia for init 165/1000: 246.696553
# Init 166/1000 with method: k-means++
# Inertia for init 166/1000: 226.138631
# Init 167/1000 with method: k-means++
# Inertia for init 167/1000: 223.550301
# Init 168/1000 with method: k-means++
# Inertia for init 168/1000: 230.917769
# Init 169/1000 with method: k-means++
# Inertia for init 169/1000: 222.186985
# Init 170/1000 with method: k-means++
# Inertia for init 170/1000: 223.592143
# Init 171/1000 with method: k-means++
# Inertia for init 171/1000: 236.540495
# Init 172/1000 with method: k-means++
# Inertia for init 172/1000: 234.640713
# Init 173/1000 with method: k-means++
# Inertia for init 173/1000: 221.152194
# Init 174/1000 with method: k-means++
# Inertia for init 174/1000: 235.060981
# Init 175/1000 with method: k-means++
# Inertia for init 175/1000: 231.858321
# Init 176/1000 with method: k-means++
# Inertia for init 176/1000: 225.577882
# Init 177/1000 with method: k-means++
# Inertia for init 177/1000: 209.721501
# Init 178/1000 with method: k-means++
# Inertia for init 178/1000: 215.221331
# Init 179/1000 with method: k-means++
# Inertia for init 179/1000: 241.583166
# Init 180/1000 with method: k-means++
# Inertia for init 180/1000: 210.747542
# Init 181/1000 with method: k-means++
# Inertia for init 181/1000: 231.918531
# Init 182/1000 with method: k-means++
# Inertia for init 182/1000: 236.293330
# Init 183/1000 with method: k-means++
# Inertia for init 183/1000: 223.373922
# Init 184/1000 with method: k-means++
# Inertia for init 184/1000: 226.419229
# Init 185/1000 with method: k-means++
# Inertia for init 185/1000: 222.137146
# Init 186/1000 with method: k-means++
# Inertia for init 186/1000: 241.789856
# Init 187/1000 with method: k-means++
# Inertia for init 187/1000: 256.695096
# Init 188/1000 with method: k-means++
# Inertia for init 188/1000: 213.159983
# Init 189/1000 with method: k-means++
# Inertia for init 189/1000: 219.046705
# Init 190/1000 with method: k-means++
# Inertia for init 190/1000: 249.222843
# Init 191/1000 with method: k-means++
# Inertia for init 191/1000: 241.365976
# Init 192/1000 with method: k-means++
# Inertia for init 192/1000: 216.301097
# Init 193/1000 with method: k-means++
# Inertia for init 193/1000: 217.976346
# Init 194/1000 with method: k-means++
# Inertia for init 194/1000: 208.688383
# Init 195/1000 with method: k-means++
# Inertia for init 195/1000: 212.866361
# Init 196/1000 with method: k-means++
# Inertia for init 196/1000: 238.589668
# Init 197/1000 with method: k-means++
# Inertia for init 197/1000: 231.976567
# Init 198/1000 with method: k-means++
# Inertia for init 198/1000: 220.805960
# Init 199/1000 with method: k-means++
# Inertia for init 199/1000: 249.998815
# Init 200/1000 with method: k-means++
# Inertia for init 200/1000: 223.539460
# Init 201/1000 with method: k-means++
# Inertia for init 201/1000: 245.531249
# Init 202/1000 with method: k-means++
# Inertia for init 202/1000: 240.309653
# Init 203/1000 with method: k-means++
# Inertia for init 203/1000: 235.684380
# Init 204/1000 with method: k-means++
# Inertia for init 204/1000: 210.124507
# Init 205/1000 with method: k-means++
# Inertia for init 205/1000: 206.181901
# Init 206/1000 with method: k-means++
# Inertia for init 206/1000: 225.189403
# Init 207/1000 with method: k-means++
# Inertia for init 207/1000: 236.887235
# Init 208/1000 with method: k-means++
# Inertia for init 208/1000: 222.252236
# Init 209/1000 with method: k-means++
# Inertia for init 209/1000: 258.908212
# Init 210/1000 with method: k-means++
# Inertia for init 210/1000: 207.469778
# Init 211/1000 with method: k-means++
# Inertia for init 211/1000: 207.910002
# Init 212/1000 with method: k-means++
# Inertia for init 212/1000: 220.242395
# Init 213/1000 with method: k-means++
# Inertia for init 213/1000: 246.290333
# Init 214/1000 with method: k-means++
# Inertia for init 214/1000: 213.741684
# Init 215/1000 with method: k-means++
# Inertia for init 215/1000: 253.539877
# Init 216/1000 with method: k-means++
# Inertia for init 216/1000: 226.219763
# Init 217/1000 with method: k-means++
# Inertia for init 217/1000: 229.457912
# Init 218/1000 with method: k-means++
# Inertia for init 218/1000: 245.720234
# Init 219/1000 with method: k-means++
# Inertia for init 219/1000: 243.263399
# Init 220/1000 with method: k-means++
# Inertia for init 220/1000: 241.967948
# Init 221/1000 with method: k-means++
# Inertia for init 221/1000: 215.140965
# Init 222/1000 with method: k-means++
# Inertia for init 222/1000: 219.831694
# Init 223/1000 with method: k-means++
# Inertia for init 223/1000: 207.393697
# Init 224/1000 with method: k-means++
# Inertia for init 224/1000: 212.298188
# Init 225/1000 with method: k-means++
# Inertia for init 225/1000: 212.981160
# Init 226/1000 with method: k-means++
# Inertia for init 226/1000: 248.362676
# Init 227/1000 with method: k-means++
# Inertia for init 227/1000: 229.126628
# Init 228/1000 with method: k-means++
# Inertia for init 228/1000: 220.091728
# Init 229/1000 with method: k-means++
# Inertia for init 229/1000: 211.537269
# Init 230/1000 with method: k-means++
# Inertia for init 230/1000: 228.258438
# Init 231/1000 with method: k-means++
# Inertia for init 231/1000: 219.399687
# Init 232/1000 with method: k-means++
# Inertia for init 232/1000: 221.723409
# Init 233/1000 with method: k-means++
# Inertia for init 233/1000: 221.582855
# Init 234/1000 with method: k-means++
# Inertia for init 234/1000: 208.906393
# Init 235/1000 with method: k-means++
# Inertia for init 235/1000: 233.446111
# Init 236/1000 with method: k-means++
# Inertia for init 236/1000: 231.263045
# Init 237/1000 with method: k-means++
# Inertia for init 237/1000: 228.051228
# Init 238/1000 with method: k-means++
# Inertia for init 238/1000: 235.099057
# Init 239/1000 with method: k-means++
# Inertia for init 239/1000: 239.720930
# Init 240/1000 with method: k-means++
# Inertia for init 240/1000: 222.007973
# Init 241/1000 with method: k-means++
# Inertia for init 241/1000: 215.691416
# Init 242/1000 with method: k-means++
# Inertia for init 242/1000: 221.556759
# Init 243/1000 with method: k-means++
# Inertia for init 243/1000: 239.511437
# Init 244/1000 with method: k-means++
# Inertia for init 244/1000: 222.965613
# Init 245/1000 with method: k-means++
# Inertia for init 245/1000: 219.739465
# Init 246/1000 with method: k-means++
# Inertia for init 246/1000: 265.827259
# Init 247/1000 with method: k-means++
# Inertia for init 247/1000: 246.319695
# Init 248/1000 with method: k-means++
# Inertia for init 248/1000: 253.788086
# Init 249/1000 with method: k-means++
# Inertia for init 249/1000: 241.906852
# Init 250/1000 with method: k-means++
# Inertia for init 250/1000: 236.196363
# Init 251/1000 with method: k-means++
# Inertia for init 251/1000: 220.551912
# Init 252/1000 with method: k-means++
# Inertia for init 252/1000: 242.234531
# Init 253/1000 with method: k-means++
# Inertia for init 253/1000: 221.651391
# Init 254/1000 with method: k-means++
# Inertia for init 254/1000: 229.772698
# Init 255/1000 with method: k-means++
# Inertia for init 255/1000: 223.844277
# Init 256/1000 with method: k-means++
# Inertia for init 256/1000: 213.690801
# Init 257/1000 with method: k-means++
# Inertia for init 257/1000: 223.485535
# Init 258/1000 with method: k-means++
# Inertia for init 258/1000: 247.326097
# Init 259/1000 with method: k-means++
# Inertia for init 259/1000: 230.187965
# Init 260/1000 with method: k-means++
# Inertia for init 260/1000: 232.512199
# Init 261/1000 with method: k-means++
# Inertia for init 261/1000: 233.560879
# Init 262/1000 with method: k-means++
# Inertia for init 262/1000: 234.455370
# Init 263/1000 with method: k-means++
# Inertia for init 263/1000: 225.697195
# Init 264/1000 with method: k-means++
# Inertia for init 264/1000: 233.742445
# Init 265/1000 with method: k-means++
# Inertia for init 265/1000: 209.614780
# Init 266/1000 with method: k-means++
# Inertia for init 266/1000: 238.584138
# Init 267/1000 with method: k-means++
# Inertia for init 267/1000: 241.493256
# Init 268/1000 with method: k-means++
# Inertia for init 268/1000: 219.606367
# Init 269/1000 with method: k-means++
# Inertia for init 269/1000: 239.118077
# Init 270/1000 with method: k-means++
# Inertia for init 270/1000: 213.047192
# Init 271/1000 with method: k-means++
# Inertia for init 271/1000: 225.081775
# Init 272/1000 with method: k-means++
# Inertia for init 272/1000: 229.763408
# Init 273/1000 with method: k-means++
# Inertia for init 273/1000: 229.480335
# Init 274/1000 with method: k-means++
# Inertia for init 274/1000: 243.056901
# Init 275/1000 with method: k-means++
# Inertia for init 275/1000: 205.909098
# Init 276/1000 with method: k-means++
# Inertia for init 276/1000: 232.520218
# Init 277/1000 with method: k-means++
# Inertia for init 277/1000: 243.916139
# Init 278/1000 with method: k-means++
# Inertia for init 278/1000: 243.004332
# Init 279/1000 with method: k-means++
# Inertia for init 279/1000: 217.224860
# Init 280/1000 with method: k-means++
# Inertia for init 280/1000: 248.865544
# Init 281/1000 with method: k-means++
# Inertia for init 281/1000: 218.805503
# Init 282/1000 with method: k-means++
# Inertia for init 282/1000: 224.494616
# Init 283/1000 with method: k-means++
# Inertia for init 283/1000: 246.947243
# Init 284/1000 with method: k-means++
# Inertia for init 284/1000: 232.934285
# Init 285/1000 with method: k-means++
# Inertia for init 285/1000: 232.766995
# Init 286/1000 with method: k-means++
# Inertia for init 286/1000: 224.809723
# Init 287/1000 with method: k-means++
# Inertia for init 287/1000: 245.692119
# Init 288/1000 with method: k-means++
# Inertia for init 288/1000: 212.639830
# Init 289/1000 with method: k-means++
# Inertia for init 289/1000: 225.270650
# Init 290/1000 with method: k-means++
# Inertia for init 290/1000: 249.120906
# Init 291/1000 with method: k-means++
# Inertia for init 291/1000: 261.033839
# Init 292/1000 with method: k-means++
# Inertia for init 292/1000: 215.803904
# Init 293/1000 with method: k-means++
# Inertia for init 293/1000: 226.495610
# Init 294/1000 with method: k-means++
# Inertia for init 294/1000: 231.647298
# Init 295/1000 with method: k-means++
# Inertia for init 295/1000: 226.030870
# Init 296/1000 with method: k-means++
# Inertia for init 296/1000: 219.447800
# Init 297/1000 with method: k-means++
# Inertia for init 297/1000: 215.451020
# Init 298/1000 with method: k-means++
# Inertia for init 298/1000: 211.540344
# Init 299/1000 with method: k-means++
# Inertia for init 299/1000: 226.149107
# Init 300/1000 with method: k-means++
# Inertia for init 300/1000: 219.095840
# Init 301/1000 with method: k-means++
# Inertia for init 301/1000: 228.298618
# Init 302/1000 with method: k-means++
# Inertia for init 302/1000: 254.334864
# Init 303/1000 with method: k-means++
# Inertia for init 303/1000: 228.722469
# Init 304/1000 with method: k-means++
# Inertia for init 304/1000: 242.394615
# Init 305/1000 with method: k-means++
# Inertia for init 305/1000: 210.959733
# Init 306/1000 with method: k-means++
# Inertia for init 306/1000: 219.572188
# Init 307/1000 with method: k-means++
# Inertia for init 307/1000: 231.997895
# Init 308/1000 with method: k-means++
# Inertia for init 308/1000: 222.752063
# Init 309/1000 with method: k-means++
# Inertia for init 309/1000: 236.230900
# Init 310/1000 with method: k-means++
# Inertia for init 310/1000: 204.435084
# Init 311/1000 with method: k-means++
# Inertia for init 311/1000: 233.728974
# Init 312/1000 with method: k-means++
# Inertia for init 312/1000: 224.370418
# Init 313/1000 with method: k-means++
# Inertia for init 313/1000: 240.919325
# Init 314/1000 with method: k-means++
# Inertia for init 314/1000: 244.311215
# Init 315/1000 with method: k-means++
# Inertia for init 315/1000: 207.007834
# Init 316/1000 with method: k-means++
# Inertia for init 316/1000: 273.509719
# Init 317/1000 with method: k-means++
# Inertia for init 317/1000: 249.532721
# Init 318/1000 with method: k-means++
# Inertia for init 318/1000: 227.941586
# Init 319/1000 with method: k-means++
# Inertia for init 319/1000: 229.853088
# Init 320/1000 with method: k-means++
# Inertia for init 320/1000: 217.059212
# Init 321/1000 with method: k-means++
# Inertia for init 321/1000: 223.448894
# Init 322/1000 with method: k-means++
# Inertia for init 322/1000: 282.370250
# Init 323/1000 with method: k-means++
# Inertia for init 323/1000: 225.182079
# Init 324/1000 with method: k-means++
# Inertia for init 324/1000: 258.728301
# Init 325/1000 with method: k-means++
# Inertia for init 325/1000: 232.774981
# Init 326/1000 with method: k-means++
# Inertia for init 326/1000: 212.820970
# Init 327/1000 with method: k-means++
# Inertia for init 327/1000: 217.669877
# Init 328/1000 with method: k-means++
# Inertia for init 328/1000: 219.717088
# Init 329/1000 with method: k-means++
# Inertia for init 329/1000: 231.229169
# Init 330/1000 with method: k-means++
# Inertia for init 330/1000: 235.621632
# Init 331/1000 with method: k-means++
# Inertia for init 331/1000: 222.896198
# Init 332/1000 with method: k-means++
# Inertia for init 332/1000: 253.100150
# Init 333/1000 with method: k-means++
# Inertia for init 333/1000: 222.552002
# Init 334/1000 with method: k-means++
# Inertia for init 334/1000: 214.217840
# Init 335/1000 with method: k-means++
# Inertia for init 335/1000: 261.661529
# Init 336/1000 with method: k-means++
# Inertia for init 336/1000: 224.580358
# Init 337/1000 with method: k-means++
# Inertia for init 337/1000: 244.409015
# Init 338/1000 with method: k-means++
# Inertia for init 338/1000: 217.620122
# Init 339/1000 with method: k-means++
# Inertia for init 339/1000: 230.810452
# Init 340/1000 with method: k-means++
# Inertia for init 340/1000: 245.800546
# Init 341/1000 with method: k-means++
# Inertia for init 341/1000: 219.923627
# Init 342/1000 with method: k-means++
# Inertia for init 342/1000: 257.405088
# Init 343/1000 with method: k-means++
# Inertia for init 343/1000: 207.737281
# Init 344/1000 with method: k-means++
# Inertia for init 344/1000: 228.006189
# Init 345/1000 with method: k-means++
# Inertia for init 345/1000: 212.827716
# Init 346/1000 with method: k-means++
# Inertia for init 346/1000: 233.332304
# Init 347/1000 with method: k-means++
# Inertia for init 347/1000: 220.489362
# Init 348/1000 with method: k-means++
# Inertia for init 348/1000: 247.847640
# Init 349/1000 with method: k-means++
# Inertia for init 349/1000: 236.246802
# Init 350/1000 with method: k-means++
# Inertia for init 350/1000: 279.673879
# Init 351/1000 with method: k-means++
# Inertia for init 351/1000: 246.951112
# Init 352/1000 with method: k-means++
# Inertia for init 352/1000: 218.097653
# Init 353/1000 with method: k-means++
# Inertia for init 353/1000: 224.853036
# Init 354/1000 with method: k-means++
# Inertia for init 354/1000: 229.558168
# Init 355/1000 with method: k-means++
# Inertia for init 355/1000: 241.789138
# Init 356/1000 with method: k-means++
# Inertia for init 356/1000: 214.550869
# Init 357/1000 with method: k-means++
# Inertia for init 357/1000: 249.473586
# Init 358/1000 with method: k-means++
# Inertia for init 358/1000: 236.602531
# Init 359/1000 with method: k-means++
# Inertia for init 359/1000: 241.312221
# Init 360/1000 with method: k-means++
# Inertia for init 360/1000: 234.779300
# Init 361/1000 with method: k-means++
# Inertia for init 361/1000: 231.043633
# Init 362/1000 with method: k-means++
# Inertia for init 362/1000: 248.638429
# Init 363/1000 with method: k-means++
# Inertia for init 363/1000: 216.292573
# Init 364/1000 with method: k-means++
# Inertia for init 364/1000: 270.389323
# Init 365/1000 with method: k-means++
# Inertia for init 365/1000: 221.554641
# Init 366/1000 with method: k-means++
# Inertia for init 366/1000: 228.999788
# Init 367/1000 with method: k-means++
# Inertia for init 367/1000: 221.463287
# Init 368/1000 with method: k-means++
# Inertia for init 368/1000: 214.002710
# Init 369/1000 with method: k-means++
# Inertia for init 369/1000: 229.435179
# Init 370/1000 with method: k-means++
# Inertia for init 370/1000: 218.764351
# Init 371/1000 with method: k-means++
# Inertia for init 371/1000: 235.149093
# Init 372/1000 with method: k-means++
# Inertia for init 372/1000: 228.234280
# Init 373/1000 with method: k-means++
# Inertia for init 373/1000: 236.770470
# Init 374/1000 with method: k-means++
# Inertia for init 374/1000: 228.179922
# Init 375/1000 with method: k-means++
# Inertia for init 375/1000: 205.707474
# Init 376/1000 with method: k-means++
# Inertia for init 376/1000: 249.967201
# Init 377/1000 with method: k-means++
# Inertia for init 377/1000: 218.782448
# Init 378/1000 with method: k-means++
# Inertia for init 378/1000: 201.786625
# Init 379/1000 with method: k-means++
# Inertia for init 379/1000: 235.656759
# Init 380/1000 with method: k-means++
# Inertia for init 380/1000: 212.172919
# Init 381/1000 with method: k-means++
# Inertia for init 381/1000: 221.335324
# Init 382/1000 with method: k-means++
# Inertia for init 382/1000: 204.470682
# Init 383/1000 with method: k-means++
# Inertia for init 383/1000: 224.948321
# Init 384/1000 with method: k-means++
# Inertia for init 384/1000: 221.990703
# Init 385/1000 with method: k-means++
# Inertia for init 385/1000: 216.961152
# Init 386/1000 with method: k-means++
# Inertia for init 386/1000: 269.006189
# Init 387/1000 with method: k-means++
# Inertia for init 387/1000: 231.238796
# Init 388/1000 with method: k-means++
# Inertia for init 388/1000: 222.542756
# Init 389/1000 with method: k-means++
# Inertia for init 389/1000: 223.237505
# Init 390/1000 with method: k-means++
# Inertia for init 390/1000: 232.855852
# Init 391/1000 with method: k-means++
# Inertia for init 391/1000: 216.305115
# Init 392/1000 with method: k-means++
# Inertia for init 392/1000: 236.898958
# Init 393/1000 with method: k-means++
# Inertia for init 393/1000: 248.667050
# Init 394/1000 with method: k-means++
# Inertia for init 394/1000: 219.504957
# Init 395/1000 with method: k-means++
# Inertia for init 395/1000: 209.135113
# Init 396/1000 with method: k-means++
# Inertia for init 396/1000: 221.977984
# Init 397/1000 with method: k-means++
# Inertia for init 397/1000: 245.843996
# Init 398/1000 with method: k-means++
# Inertia for init 398/1000: 204.913516
# Init 399/1000 with method: k-means++
# Inertia for init 399/1000: 250.812767
# Init 400/1000 with method: k-means++
# Inertia for init 400/1000: 206.992907
# Init 401/1000 with method: k-means++
# Inertia for init 401/1000: 228.639154
# Init 402/1000 with method: k-means++
# Inertia for init 402/1000: 243.138407
# Init 403/1000 with method: k-means++
# Inertia for init 403/1000: 224.160764
# Init 404/1000 with method: k-means++
# Inertia for init 404/1000: 215.875822
# Init 405/1000 with method: k-means++
# Inertia for init 405/1000: 233.273439
# Init 406/1000 with method: k-means++
# Inertia for init 406/1000: 243.804282
# Init 407/1000 with method: k-means++
# Inertia for init 407/1000: 216.156874
# Init 408/1000 with method: k-means++
# Inertia for init 408/1000: 239.812601
# Init 409/1000 with method: k-means++
# Inertia for init 409/1000: 212.039511
# Init 410/1000 with method: k-means++
# Inertia for init 410/1000: 223.133911
# Init 411/1000 with method: k-means++
# Inertia for init 411/1000: 227.929249
# Init 412/1000 with method: k-means++
# Inertia for init 412/1000: 243.663944
# Init 413/1000 with method: k-means++
# Inertia for init 413/1000: 215.970232
# Init 414/1000 with method: k-means++
# Inertia for init 414/1000: 221.624834
# Init 415/1000 with method: k-means++
# Inertia for init 415/1000: 237.623915
# Init 416/1000 with method: k-means++
# Inertia for init 416/1000: 281.002779
# Init 417/1000 with method: k-means++
# Inertia for init 417/1000: 235.151463
# Init 418/1000 with method: k-means++
# Inertia for init 418/1000: 224.432360
# Init 419/1000 with method: k-means++
# Inertia for init 419/1000: 210.087213
# Init 420/1000 with method: k-means++
# Inertia for init 420/1000: 215.233857
# Init 421/1000 with method: k-means++
# Inertia for init 421/1000: 218.367818
# Init 422/1000 with method: k-means++
# Inertia for init 422/1000: 254.997951
# Init 423/1000 with method: k-means++
# Inertia for init 423/1000: 233.211724
# Init 424/1000 with method: k-means++
# Inertia for init 424/1000: 230.918985
# Init 425/1000 with method: k-means++
# Inertia for init 425/1000: 237.422828
# Init 426/1000 with method: k-means++
# Inertia for init 426/1000: 264.076544
# Init 427/1000 with method: k-means++
# Inertia for init 427/1000: 235.200720
# Init 428/1000 with method: k-means++
# Inertia for init 428/1000: 246.624109
# Init 429/1000 with method: k-means++
# Inertia for init 429/1000: 220.850112
# Init 430/1000 with method: k-means++
# Inertia for init 430/1000: 224.987486
# Init 431/1000 with method: k-means++
# Inertia for init 431/1000: 221.791793
# Init 432/1000 with method: k-means++
# Inertia for init 432/1000: 227.273653
# Init 433/1000 with method: k-means++
# Inertia for init 433/1000: 247.411679
# Init 434/1000 with method: k-means++
# Inertia for init 434/1000: 226.386988
# Init 435/1000 with method: k-means++
# Inertia for init 435/1000: 227.709143
# Init 436/1000 with method: k-means++
# Inertia for init 436/1000: 264.389556
# Init 437/1000 with method: k-means++
# Inertia for init 437/1000: 244.903456
# Init 438/1000 with method: k-means++
# Inertia for init 438/1000: 204.441592
# Init 439/1000 with method: k-means++
# Inertia for init 439/1000: 229.352258
# Init 440/1000 with method: k-means++
# Inertia for init 440/1000: 229.241108
# Init 441/1000 with method: k-means++
# Inertia for init 441/1000: 219.625485
# Init 442/1000 with method: k-means++
# Inertia for init 442/1000: 222.147474
# Init 443/1000 with method: k-means++
# Inertia for init 443/1000: 218.368133
# Init 444/1000 with method: k-means++
# Inertia for init 444/1000: 254.259288
# Init 445/1000 with method: k-means++
# Inertia for init 445/1000: 214.977472
# Init 446/1000 with method: k-means++
# Inertia for init 446/1000: 222.554705
# Init 447/1000 with method: k-means++
# Inertia for init 447/1000: 252.685665
# Init 448/1000 with method: k-means++
# Inertia for init 448/1000: 235.113935
# Init 449/1000 with method: k-means++
# Inertia for init 449/1000: 238.094712
# Init 450/1000 with method: k-means++
# Inertia for init 450/1000: 219.963202
# Init 451/1000 with method: k-means++
# Inertia for init 451/1000: 234.325689
# Init 452/1000 with method: k-means++
# Inertia for init 452/1000: 228.044626
# Init 453/1000 with method: k-means++
# Inertia for init 453/1000: 219.825394
# Init 454/1000 with method: k-means++
# Inertia for init 454/1000: 230.243078
# Init 455/1000 with method: k-means++
# Inertia for init 455/1000: 236.349817
# Init 456/1000 with method: k-means++
# Inertia for init 456/1000: 227.683293
# Init 457/1000 with method: k-means++
# Inertia for init 457/1000: 209.433062
# Init 458/1000 with method: k-means++
# Inertia for init 458/1000: 225.856160
# Init 459/1000 with method: k-means++
# Inertia for init 459/1000: 218.417907
# Init 460/1000 with method: k-means++
# Inertia for init 460/1000: 219.751155
# Init 461/1000 with method: k-means++
# Inertia for init 461/1000: 237.857473
# Init 462/1000 with method: k-means++
# Inertia for init 462/1000: 207.877045
# Init 463/1000 with method: k-means++
# Inertia for init 463/1000: 217.833919
# Init 464/1000 with method: k-means++
# Inertia for init 464/1000: 218.860749
# Init 465/1000 with method: k-means++
# Inertia for init 465/1000: 221.375404
# Init 466/1000 with method: k-means++
# Inertia for init 466/1000: 252.590749
# Init 467/1000 with method: k-means++
# Inertia for init 467/1000: 218.850051
# Init 468/1000 with method: k-means++
# Inertia for init 468/1000: 203.076493
# Init 469/1000 with method: k-means++
# Inertia for init 469/1000: 231.333495
# Init 470/1000 with method: k-means++
# Inertia for init 470/1000: 228.176249
# Init 471/1000 with method: k-means++
# Inertia for init 471/1000: 230.098651
# Init 472/1000 with method: k-means++
# Inertia for init 472/1000: 226.755071
# Init 473/1000 with method: k-means++
# Inertia for init 473/1000: 220.381391
# Init 474/1000 with method: k-means++
# Inertia for init 474/1000: 258.235356
# Init 475/1000 with method: k-means++
# Inertia for init 475/1000: 222.351901
# Init 476/1000 with method: k-means++
# Inertia for init 476/1000: 230.071805
# Init 477/1000 with method: k-means++
# Inertia for init 477/1000: 264.481319
# Init 478/1000 with method: k-means++
# Inertia for init 478/1000: 215.574812
# Init 479/1000 with method: k-means++
# Inertia for init 479/1000: 224.108277
# Init 480/1000 with method: k-means++
# Inertia for init 480/1000: 248.500850
# Init 481/1000 with method: k-means++
# Inertia for init 481/1000: 222.256489
# Init 482/1000 with method: k-means++
# Inertia for init 482/1000: 250.915314
# Init 483/1000 with method: k-means++
# Inertia for init 483/1000: 233.764635
# Init 484/1000 with method: k-means++
# Inertia for init 484/1000: 219.437850
# Init 485/1000 with method: k-means++
# Inertia for init 485/1000: 233.816279
# Init 486/1000 with method: k-means++
# Inertia for init 486/1000: 210.265058
# Init 487/1000 with method: k-means++
# Inertia for init 487/1000: 230.346494
# Init 488/1000 with method: k-means++
# Inertia for init 488/1000: 239.816811
# Init 489/1000 with method: k-means++
# Inertia for init 489/1000: 233.674061
# Init 490/1000 with method: k-means++
# Inertia for init 490/1000: 242.971748
# Init 491/1000 with method: k-means++
# Inertia for init 491/1000: 229.518034
# Init 492/1000 with method: k-means++
# Inertia for init 492/1000: 219.725588
# Init 493/1000 with method: k-means++
# Inertia for init 493/1000: 223.029143
# Init 494/1000 with method: k-means++
# Inertia for init 494/1000: 250.165831
# Init 495/1000 with method: k-means++
# Inertia for init 495/1000: 248.499022
# Init 496/1000 with method: k-means++
# Inertia for init 496/1000: 226.244182
# Init 497/1000 with method: k-means++
# Inertia for init 497/1000: 219.456093
# Init 498/1000 with method: k-means++
# Inertia for init 498/1000: 246.610213
# Init 499/1000 with method: k-means++
# Inertia for init 499/1000: 222.108200
# Init 500/1000 with method: k-means++
# Inertia for init 500/1000: 227.251888
# Init 501/1000 with method: k-means++
# Inertia for init 501/1000: 221.898501
# Init 502/1000 with method: k-means++
# Inertia for init 502/1000: 241.121380
# Init 503/1000 with method: k-means++
# Inertia for init 503/1000: 225.001227
# Init 504/1000 with method: k-means++
# Inertia for init 504/1000: 261.636115
# Init 505/1000 with method: k-means++
# Inertia for init 505/1000: 227.728564
# Init 506/1000 with method: k-means++
# Inertia for init 506/1000: 221.243415
# Init 507/1000 with method: k-means++
# Inertia for init 507/1000: 233.072061
# Init 508/1000 with method: k-means++
# Inertia for init 508/1000: 252.407662
# Init 509/1000 with method: k-means++
# Inertia for init 509/1000: 226.552379
# Init 510/1000 with method: k-means++
# Inertia for init 510/1000: 221.638531
# Init 511/1000 with method: k-means++
# Inertia for init 511/1000: 240.393730
# Init 512/1000 with method: k-means++
# Inertia for init 512/1000: 225.337000
# Init 513/1000 with method: k-means++
# Inertia for init 513/1000: 210.674384
# Init 514/1000 with method: k-means++
# Inertia for init 514/1000: 244.773706
# Init 515/1000 with method: k-means++
# Inertia for init 515/1000: 244.560883
# Init 516/1000 with method: k-means++
# Inertia for init 516/1000: 207.918102
# Init 517/1000 with method: k-means++
# Inertia for init 517/1000: 229.567336
# Init 518/1000 with method: k-means++
# Inertia for init 518/1000: 225.045350
# Init 519/1000 with method: k-means++
# Inertia for init 519/1000: 237.481426
# Init 520/1000 with method: k-means++
# Inertia for init 520/1000: 235.746411
# Init 521/1000 with method: k-means++
# Inertia for init 521/1000: 210.838433
# Init 522/1000 with method: k-means++
# Inertia for init 522/1000: 229.435262
# Init 523/1000 with method: k-means++
# Inertia for init 523/1000: 263.969608
# Init 524/1000 with method: k-means++
# Inertia for init 524/1000: 234.167728
# Init 525/1000 with method: k-means++
# Inertia for init 525/1000: 234.762612
# Init 526/1000 with method: k-means++
# Inertia for init 526/1000: 215.655732
# Init 527/1000 with method: k-means++
# Inertia for init 527/1000: 247.470147
# Init 528/1000 with method: k-means++
# Inertia for init 528/1000: 234.332659
# Init 529/1000 with method: k-means++
# Inertia for init 529/1000: 298.685171
# Init 530/1000 with method: k-means++
# Inertia for init 530/1000: 214.395140
# Init 531/1000 with method: k-means++
# Inertia for init 531/1000: 231.008827
# Init 532/1000 with method: k-means++
# Inertia for init 532/1000: 277.974943
# Init 533/1000 with method: k-means++
# Inertia for init 533/1000: 207.283751
# Init 534/1000 with method: k-means++
# Inertia for init 534/1000: 244.767428
# Init 535/1000 with method: k-means++
# Inertia for init 535/1000: 236.755012
# Init 536/1000 with method: k-means++
# Inertia for init 536/1000: 235.956958
# Init 537/1000 with method: k-means++
# Inertia for init 537/1000: 247.771333
# Init 538/1000 with method: k-means++
# Inertia for init 538/1000: 206.394809
# Init 539/1000 with method: k-means++
# Inertia for init 539/1000: 239.993427
# Init 540/1000 with method: k-means++
# Inertia for init 540/1000: 217.363268
# Init 541/1000 with method: k-means++
# Inertia for init 541/1000: 236.139224
# Init 542/1000 with method: k-means++
# Inertia for init 542/1000: 232.786964
# Init 543/1000 with method: k-means++
# Inertia for init 543/1000: 257.204560
# Init 544/1000 with method: k-means++
# Inertia for init 544/1000: 245.292875
# Init 545/1000 with method: k-means++
# Inertia for init 545/1000: 224.584343
# Init 546/1000 with method: k-means++
# Inertia for init 546/1000: 214.488950
# Init 547/1000 with method: k-means++
# Inertia for init 547/1000: 254.258401
# Init 548/1000 with method: k-means++
# Inertia for init 548/1000: 243.400474
# Init 549/1000 with method: k-means++
# Inertia for init 549/1000: 242.427164
# Init 550/1000 with method: k-means++
# Inertia for init 550/1000: 216.496711
# Init 551/1000 with method: k-means++
# Inertia for init 551/1000: 226.269694
# Init 552/1000 with method: k-means++
# Inertia for init 552/1000: 233.655270
# Init 553/1000 with method: k-means++
# Inertia for init 553/1000: 246.904638
# Init 554/1000 with method: k-means++
# Inertia for init 554/1000: 235.882899
# Init 555/1000 with method: k-means++
# Inertia for init 555/1000: 264.180383
# Init 556/1000 with method: k-means++
# Inertia for init 556/1000: 212.105416
# Init 557/1000 with method: k-means++
# Inertia for init 557/1000: 236.117096
# Init 558/1000 with method: k-means++
# Inertia for init 558/1000: 222.865601
# Init 559/1000 with method: k-means++
# Inertia for init 559/1000: 218.663058
# Init 560/1000 with method: k-means++
# Inertia for init 560/1000: 272.966466
# Init 561/1000 with method: k-means++
# Inertia for init 561/1000: 223.627063
# Init 562/1000 with method: k-means++
# Inertia for init 562/1000: 225.212943
# Init 563/1000 with method: k-means++
# Inertia for init 563/1000: 233.178317
# Init 564/1000 with method: k-means++
# Inertia for init 564/1000: 212.665492
# Init 565/1000 with method: k-means++
# Inertia for init 565/1000: 235.187264
# Init 566/1000 with method: k-means++
# Inertia for init 566/1000: 229.091651
# Init 567/1000 with method: k-means++
# Inertia for init 567/1000: 242.511595
# Init 568/1000 with method: k-means++
# Inertia for init 568/1000: 263.151459
# Init 569/1000 with method: k-means++
# Inertia for init 569/1000: 230.538909
# Init 570/1000 with method: k-means++
# Inertia for init 570/1000: 228.037148
# Init 571/1000 with method: k-means++
# Inertia for init 571/1000: 204.203174
# Init 572/1000 with method: k-means++
# Inertia for init 572/1000: 226.019826
# Init 573/1000 with method: k-means++
# Inertia for init 573/1000: 220.474000
# Init 574/1000 with method: k-means++
# Inertia for init 574/1000: 237.491134
# Init 575/1000 with method: k-means++
# Inertia for init 575/1000: 248.187791
# Init 576/1000 with method: k-means++
# Inertia for init 576/1000: 233.367120
# Init 577/1000 with method: k-means++
# Inertia for init 577/1000: 234.433789
# Init 578/1000 with method: k-means++
# Inertia for init 578/1000: 246.955830
# Init 579/1000 with method: k-means++
# Inertia for init 579/1000: 211.394417
# Init 580/1000 with method: k-means++
# Inertia for init 580/1000: 221.039632
# Init 581/1000 with method: k-means++
# Inertia for init 581/1000: 240.213388
# Init 582/1000 with method: k-means++
# Inertia for init 582/1000: 221.981912
# Init 583/1000 with method: k-means++
# Inertia for init 583/1000: 252.262637
# Init 584/1000 with method: k-means++
# Inertia for init 584/1000: 228.237424
# Init 585/1000 with method: k-means++
# Inertia for init 585/1000: 220.398786
# Init 586/1000 with method: k-means++
# Inertia for init 586/1000: 218.736957
# Init 587/1000 with method: k-means++
# Inertia for init 587/1000: 237.432302
# Init 588/1000 with method: k-means++
# Inertia for init 588/1000: 242.637561
# Init 589/1000 with method: k-means++
# Inertia for init 589/1000: 267.458908
# Init 590/1000 with method: k-means++
# Inertia for init 590/1000: 225.964176
# Init 591/1000 with method: k-means++
# Inertia for init 591/1000: 206.167791
# Init 592/1000 with method: k-means++
# Inertia for init 592/1000: 239.290628
# Init 593/1000 with method: k-means++
# Inertia for init 593/1000: 232.520128
# Init 594/1000 with method: k-means++
# Inertia for init 594/1000: 225.958885
# Init 595/1000 with method: k-means++
# Inertia for init 595/1000: 232.882745
# Init 596/1000 with method: k-means++
# Inertia for init 596/1000: 230.328459
# Init 597/1000 with method: k-means++
# Inertia for init 597/1000: 263.155127
# Init 598/1000 with method: k-means++
# Inertia for init 598/1000: 235.205354
# Init 599/1000 with method: k-means++
# Inertia for init 599/1000: 234.033614
# Init 600/1000 with method: k-means++
# Inertia for init 600/1000: 217.045853
# Init 601/1000 with method: k-means++
# Inertia for init 601/1000: 237.152262
# Init 602/1000 with method: k-means++
# Inertia for init 602/1000: 241.778246
# Init 603/1000 with method: k-means++
# Inertia for init 603/1000: 219.848168
# Init 604/1000 with method: k-means++
# Inertia for init 604/1000: 255.244349
# Init 605/1000 with method: k-means++
# Inertia for init 605/1000: 223.047648
# Init 606/1000 with method: k-means++
# Inertia for init 606/1000: 219.523054
# Init 607/1000 with method: k-means++
# Inertia for init 607/1000: 219.275773
# Init 608/1000 with method: k-means++
# Inertia for init 608/1000: 218.352786
# Init 609/1000 with method: k-means++
# Inertia for init 609/1000: 218.898648
# Init 610/1000 with method: k-means++
# Inertia for init 610/1000: 227.553821
# Init 611/1000 with method: k-means++
# Inertia for init 611/1000: 232.149949
# Init 612/1000 with method: k-means++
# Inertia for init 612/1000: 236.892579
# Init 613/1000 with method: k-means++
# Inertia for init 613/1000: 217.511727
# Init 614/1000 with method: k-means++
# Inertia for init 614/1000: 216.742886
# Init 615/1000 with method: k-means++
# Inertia for init 615/1000: 205.729334
# Init 616/1000 with method: k-means++
# Inertia for init 616/1000: 214.610446
# Init 617/1000 with method: k-means++
# Inertia for init 617/1000: 215.749666
# Init 618/1000 with method: k-means++
# Inertia for init 618/1000: 217.662199
# Init 619/1000 with method: k-means++
# Inertia for init 619/1000: 224.471270
# Init 620/1000 with method: k-means++
# Inertia for init 620/1000: 252.637336
# Init 621/1000 with method: k-means++
# Inertia for init 621/1000: 222.098790
# Init 622/1000 with method: k-means++
# Inertia for init 622/1000: 242.997316
# Init 623/1000 with method: k-means++
# Inertia for init 623/1000: 241.668193
# Init 624/1000 with method: k-means++
# Inertia for init 624/1000: 222.528196
# Init 625/1000 with method: k-means++
# Inertia for init 625/1000: 227.348323
# Init 626/1000 with method: k-means++
# Inertia for init 626/1000: 216.618330
# Init 627/1000 with method: k-means++
# Inertia for init 627/1000: 215.855365
# Init 628/1000 with method: k-means++
# Inertia for init 628/1000: 245.545005
# Init 629/1000 with method: k-means++
# Inertia for init 629/1000: 252.991555
# Init 630/1000 with method: k-means++
# Inertia for init 630/1000: 237.190527
# Init 631/1000 with method: k-means++
# Inertia for init 631/1000: 207.117909
# Init 632/1000 with method: k-means++
# Inertia for init 632/1000: 268.511466
# Init 633/1000 with method: k-means++
# Inertia for init 633/1000: 227.571909
# Init 634/1000 with method: k-means++
# Inertia for init 634/1000: 243.066167
# Init 635/1000 with method: k-means++
# Inertia for init 635/1000: 222.270447
# Init 636/1000 with method: k-means++
# Inertia for init 636/1000: 230.661865
# Init 637/1000 with method: k-means++
# Inertia for init 637/1000: 235.745883
# Init 638/1000 with method: k-means++
# Inertia for init 638/1000: 237.634876
# Init 639/1000 with method: k-means++
# Inertia for init 639/1000: 259.117879
# Init 640/1000 with method: k-means++
# Inertia for init 640/1000: 220.515860
# Init 641/1000 with method: k-means++
# Inertia for init 641/1000: 242.144349
# Init 642/1000 with method: k-means++
# Inertia for init 642/1000: 245.872930
# Init 643/1000 with method: k-means++
# ...
# Init 824/1000 with method: k-means++
# Inertia for init 824/1000: 210.515408
# Init 825/1000 with method: k-means++
# Inertia for init 825/1000: 231.918159
# Init 826/1000 with method: k-means++
# Inertia for init 826/1000: 236.413641
# Init 827/1000 with method: k-means++
# Inertia for init 827/1000: 220.447092
# Init 828/1000 with method: k-means++
# Inertia for init 828/1000: 208.734964
# Init 829/1000 with method: k-means++
# Inertia for init 829/1000: 245.028856
# Init 830/1000 with method: k-means++
# Inertia for init 830/1000: 234.699947
# Init 831/1000 with method: k-means++
# Inertia for init 831/1000: 246.160607
# Init 832/1000 with method: k-means++
# Inertia for init 832/1000: 230.250455
# Init 833/1000 with method: k-means++
# Inertia for init 833/1000: 243.806876
# Init 834/1000 with method: k-means++
# Inertia for init 834/1000: 223.520330
# Init 835/1000 with method: k-means++
# Inertia for init 835/1000: 229.508983
# Init 836/1000 with method: k-means++
# Inertia for init 836/1000: 240.060882
# Init 837/1000 with method: k-means++
# Inertia for init 837/1000: 234.945234
# Init 838/1000 with method: k-means++
# Inertia for init 838/1000: 227.379985
# Init 839/1000 with method: k-means++
# Inertia for init 839/1000: 220.434404
# Init 840/1000 with method: k-means++
# Inertia for init 840/1000: 216.767085
# Init 841/1000 with method: k-means++
# Inertia for init 841/1000: 229.497456
# Init 842/1000 with method: k-means++
# Inertia for init 842/1000: 212.913603
# Init 843/1000 with method: k-means++
# Inertia for init 843/1000: 254.175182
# Init 844/1000 with method: k-means++
# Inertia for init 844/1000: 241.895526
# Init 845/1000 with method: k-means++
# Inertia for init 845/1000: 230.904771
# Init 846/1000 with method: k-means++
# Inertia for init 846/1000: 233.053448
# Init 847/1000 with method: k-means++
# Inertia for init 847/1000: 236.551275
# Init 848/1000 with method: k-means++
# Inertia for init 848/1000: 261.715430
# Init 849/1000 with method: k-means++
# Inertia for init 849/1000: 223.563006
# Init 850/1000 with method: k-means++
# Inertia for init 850/1000: 226.542850
# Init 851/1000 with method: k-means++
# Inertia for init 851/1000: 229.559318
# Init 852/1000 with method: k-means++
# Inertia for init 852/1000: 217.996607
# Init 853/1000 with method: k-means++
# Inertia for init 853/1000: 214.606971
# Init 854/1000 with method: k-means++
# Inertia for init 854/1000: 217.084921
# Init 855/1000 with method: k-means++
# Inertia for init 855/1000: 210.434615
# Init 856/1000 with method: k-means++
# Inertia for init 856/1000: 237.947503
# Init 857/1000 with method: k-means++
# Inertia for init 857/1000: 206.901469
# Init 858/1000 with method: k-means++
# Inertia for init 858/1000: 221.790487
# Init 859/1000 with method: k-means++
# Inertia for init 859/1000: 208.901842
# Init 860/1000 with method: k-means++
# Inertia for init 860/1000: 260.759465
# Init 861/1000 with method: k-means++
# Inertia for init 861/1000: 240.583966
# Init 862/1000 with method: k-means++
# Inertia for init 862/1000: 241.327136
# Init 863/1000 with method: k-means++
# Inertia for init 863/1000: 265.538667
# Init 864/1000 with method: k-means++
# Inertia for init 864/1000: 230.447566
# Init 865/1000 with method: k-means++
# Inertia for init 865/1000: 245.326224
# Init 866/1000 with method: k-means++
# Inertia for init 866/1000: 219.410806
# Init 867/1000 with method: k-means++
# Inertia for init 867/1000: 253.388596
# Init 868/1000 with method: k-means++
# Inertia for init 868/1000: 232.338581
# Init 869/1000 with method: k-means++
# Inertia for init 869/1000: 224.803218
# Init 870/1000 with method: k-means++
# Inertia for init 870/1000: 236.131825
# Init 871/1000 with method: k-means++
# Inertia for init 871/1000: 242.941153
# Init 872/1000 with method: k-means++
# Inertia for init 872/1000: 236.917421
# Init 873/1000 with method: k-means++
# Inertia for init 873/1000: 218.716141
# Init 874/1000 with method: k-means++
# Inertia for init 874/1000: 236.121723
# Init 875/1000 with method: k-means++
# Inertia for init 875/1000: 261.234220
# Init 876/1000 with method: k-means++
# Inertia for init 876/1000: 232.046653
# Init 877/1000 with method: k-means++
# Inertia for init 877/1000: 247.495806
# Init 878/1000 with method: k-means++
# Inertia for init 878/1000: 227.914387
# Init 879/1000 with method: k-means++
# Inertia for init 879/1000: 239.140380
# Init 880/1000 with method: k-means++
# Inertia for init 880/1000: 240.502641
# Init 881/1000 with method: k-means++
# Inertia for init 881/1000: 222.662205
# Init 882/1000 with method: k-means++
# Inertia for init 882/1000: 233.196665
# Init 883/1000 with method: k-means++
# Inertia for init 883/1000: 236.509127
# Init 884/1000 with method: k-means++
# Inertia for init 884/1000: 227.151830
# Init 885/1000 with method: k-means++
# Inertia for init 885/1000: 242.872081
# Init 886/1000 with method: k-means++
# Inertia for init 886/1000: 273.543430
# Init 887/1000 with method: k-means++
# Inertia for init 887/1000: 206.395280
# Init 888/1000 with method: k-means++
# Inertia for init 888/1000: 209.605645
# Init 889/1000 with method: k-means++
# Inertia for init 889/1000: 236.738648
# Init 890/1000 with method: k-means++
# Inertia for init 890/1000: 225.717382
# Init 891/1000 with method: k-means++
# Inertia for init 891/1000: 245.168169
# Init 892/1000 with method: k-means++
# Inertia for init 892/1000: 258.303930
# Init 893/1000 with method: k-means++
# Inertia for init 893/1000: 251.680161
# Init 894/1000 with method: k-means++
# Inertia for init 894/1000: 221.441841
# Init 895/1000 with method: k-means++
# Inertia for init 895/1000: 256.903489
# Init 896/1000 with method: k-means++
# Inertia for init 896/1000: 223.958147
# Init 897/1000 with method: k-means++
# Inertia for init 897/1000: 253.464383
# Init 898/1000 with method: k-means++
# Inertia for init 898/1000: 250.922985
# Init 899/1000 with method: k-means++
# Inertia for init 899/1000: 274.691312
# Init 900/1000 with method: k-means++
# Inertia for init 900/1000: 235.844033
# Init 901/1000 with method: k-means++
# Inertia for init 901/1000: 255.917893
# Init 902/1000 with method: k-means++
# Inertia for init 902/1000: 221.911002
# Init 903/1000 with method: k-means++
# Inertia for init 903/1000: 241.199102
# Init 904/1000 with method: k-means++
# Inertia for init 904/1000: 228.474252
# Init 905/1000 with method: k-means++
# Inertia for init 905/1000: 209.199170
# Init 906/1000 with method: k-means++
# Inertia for init 906/1000: 228.410638
# Init 907/1000 with method: k-means++
# Inertia for init 907/1000: 245.131787
# Init 908/1000 with method: k-means++
# Inertia for init 908/1000: 253.484054
# Init 909/1000 with method: k-means++
# Inertia for init 909/1000: 258.148771
# Init 910/1000 with method: k-means++
# Inertia for init 910/1000: 209.090625
# Init 911/1000 with method: k-means++
# Inertia for init 911/1000: 253.775462
# Init 912/1000 with method: k-means++
# Inertia for init 912/1000: 239.454678
# Init 913/1000 with method: k-means++
# Inertia for init 913/1000: 238.949389
# Init 914/1000 with method: k-means++
# Inertia for init 914/1000: 223.954730
# Init 915/1000 with method: k-means++
# Inertia for init 915/1000: 269.377357
# Init 916/1000 with method: k-means++
# Inertia for init 916/1000: 216.957201
# Init 917/1000 with method: k-means++
# Inertia for init 917/1000: 211.130142
# Init 918/1000 with method: k-means++
# Inertia for init 918/1000: 221.877312
# Init 919/1000 with method: k-means++
# Inertia for init 919/1000: 248.862864
# Init 920/1000 with method: k-means++
# Inertia for init 920/1000: 252.110107
# Init 921/1000 with method: k-means++
# Inertia for init 921/1000: 212.003186
# Init 922/1000 with method: k-means++
# Inertia for init 922/1000: 207.934440
# Init 923/1000 with method: k-means++
# Inertia for init 923/1000: 249.623104
# Init 924/1000 with method: k-means++
# Inertia for init 924/1000: 205.433547
# Init 925/1000 with method: k-means++
# Inertia for init 925/1000: 250.912267
# Init 926/1000 with method: k-means++
# Inertia for init 926/1000: 229.522139
# Init 927/1000 with method: k-means++
# Inertia for init 927/1000: 224.324496
# Init 928/1000 with method: k-means++
# Inertia for init 928/1000: 224.596636
# Init 929/1000 with method: k-means++
# Inertia for init 929/1000: 247.078373
# Init 930/1000 with method: k-means++
# Inertia for init 930/1000: 229.088539
# Init 931/1000 with method: k-means++
# Inertia for init 931/1000: 222.655756
# Init 932/1000 with method: k-means++
# Inertia for init 932/1000: 222.880223
# Init 933/1000 with method: k-means++
# Inertia for init 933/1000: 211.939729
# Init 934/1000 with method: k-means++
# Inertia for init 934/1000: 240.358935
# Init 935/1000 with method: k-means++
# Inertia for init 935/1000: 225.568343
# Init 936/1000 with method: k-means++
# Inertia for init 936/1000: 234.959136
# Init 937/1000 with method: k-means++
# Inertia for init 937/1000: 218.280675
# Init 938/1000 with method: k-means++
# Inertia for init 938/1000: 218.527267
# Init 939/1000 with method: k-means++
# Inertia for init 939/1000: 205.894330
# Init 940/1000 with method: k-means++
# Inertia for init 940/1000: 241.659120
# Init 941/1000 with method: k-means++
# Inertia for init 941/1000: 202.837673
# Init 942/1000 with method: k-means++
# Inertia for init 942/1000: 241.168736
# Init 943/1000 with method: k-means++
# Inertia for init 943/1000: 228.843854
# Init 944/1000 with method: k-means++
# Inertia for init 944/1000: 208.875207
# Init 945/1000 with method: k-means++
# Inertia for init 945/1000: 219.006125
# Init 946/1000 with method: k-means++
# Inertia for init 946/1000: 263.417021
# Init 947/1000 with method: k-means++
# Inertia for init 947/1000: 218.461109
# Init 948/1000 with method: k-means++
# Inertia for init 948/1000: 243.393520
# Init 949/1000 with method: k-means++
# Inertia for init 949/1000: 220.284143
# Init 950/1000 with method: k-means++
# Inertia for init 950/1000: 219.490462
# Init 951/1000 with method: k-means++
# Inertia for init 951/1000: 234.950000
# Init 952/1000 with method: k-means++
# Inertia for init 952/1000: 230.373796
# Init 953/1000 with method: k-means++
# Inertia for init 953/1000: 222.718070
# Init 954/1000 with method: k-means++
# Inertia for init 954/1000: 249.895092
# Init 955/1000 with method: k-means++
# Inertia for init 955/1000: 260.554059
# Init 956/1000 with method: k-means++
# Inertia for init 956/1000: 215.411093
# Init 957/1000 with method: k-means++
# Inertia for init 957/1000: 229.079790
# Init 958/1000 with method: k-means++
# Inertia for init 958/1000: 247.214229
# Init 959/1000 with method: k-means++
# Inertia for init 959/1000: 232.959465
# Init 960/1000 with method: k-means++
# Inertia for init 960/1000: 225.162403
# Init 961/1000 with method: k-means++
# Inertia for init 961/1000: 213.120387
# Init 962/1000 with method: k-means++
# Inertia for init 962/1000: 260.838839
# Init 963/1000 with method: k-means++
# Inertia for init 963/1000: 255.426591
# Init 964/1000 with method: k-means++
# Inertia for init 964/1000: 229.852710
# Init 965/1000 with method: k-means++
# Inertia for init 965/1000: 238.407154
# Init 966/1000 with method: k-means++
# Inertia for init 966/1000: 229.632550
# Init 967/1000 with method: k-means++
# Inertia for init 967/1000: 229.399218
# Init 968/1000 with method: k-means++
# Inertia for init 968/1000: 212.786454
# Init 969/1000 with method: k-means++
# Inertia for init 969/1000: 227.306519
# Init 970/1000 with method: k-means++
# Inertia for init 970/1000: 249.241454
# Init 971/1000 with method: k-means++
# Inertia for init 971/1000: 239.165915
# Init 972/1000 with method: k-means++
# Inertia for init 972/1000: 230.451521
# Init 973/1000 with method: k-means++
# Inertia for init 973/1000: 214.580507
# Init 974/1000 with method: k-means++
# Inertia for init 974/1000: 227.773351
# Init 975/1000 with method: k-means++
# Inertia for init 975/1000: 228.723126
# Init 976/1000 with method: k-means++
# Inertia for init 976/1000: 206.940539
# Init 977/1000 with method: k-means++
# Inertia for init 977/1000: 207.816907
# Init 978/1000 with method: k-means++
# Inertia for init 978/1000: 220.921371
# Init 979/1000 with method: k-means++
# Inertia for init 979/1000: 229.989163
# Init 980/1000 with method: k-means++
# Inertia for init 980/1000: 233.845705
# Init 981/1000 with method: k-means++
# Inertia for init 981/1000: 233.797069
# Init 982/1000 with method: k-means++
# Inertia for init 982/1000: 207.139298
# Init 983/1000 with method: k-means++
# Inertia for init 983/1000: 228.010699
# Init 984/1000 with method: k-means++
# Inertia for init 984/1000: 256.663611
# Init 985/1000 with method: k-means++
# Inertia for init 985/1000: 216.982896
# Init 986/1000 with method: k-means++
# Inertia for init 986/1000: 239.445256
# Init 987/1000 with method: k-means++
# Inertia for init 987/1000: 250.285083
# Init 988/1000 with method: k-means++
# Inertia for init 988/1000: 233.223327
# Init 989/1000 with method: k-means++
# Inertia for init 989/1000: 240.078239
# Init 990/1000 with method: k-means++
# Inertia for init 990/1000: 246.129276
# Init 991/1000 with method: k-means++
# Inertia for init 991/1000: 236.319976
# Init 992/1000 with method: k-means++
# Inertia for init 992/1000: 265.669802
# Init 993/1000 with method: k-means++
# Inertia for init 993/1000: 210.677422
# Init 994/1000 with method: k-means++
# Inertia for init 994/1000: 226.910320
# Init 995/1000 with method: k-means++
# Inertia for init 995/1000: 234.688762
# Init 996/1000 with method: k-means++
# Inertia for init 996/1000: 254.841218
# Init 997/1000 with method: k-means++
# Inertia for init 997/1000: 218.773193
# Init 998/1000 with method: k-means++
# Inertia for init 998/1000: 220.920115
# Init 999/1000 with method: k-means++
# Inertia for init 999/1000: 227.769435
# Init 1000/1000 with method: k-means++
# Inertia for init 1000/1000: 232.074614
# Minibatch iteration 1/1300: mean batch inertia: 0.784588, ewa inertia: 0.784588
# Minibatch iteration 2/1300: mean batch inertia: 0.682968, ewa inertia: 0.768894
# Minibatch iteration 3/1300: mean batch inertia: 0.705895, ewa inertia: 0.759164
# Minibatch iteration 4/1300: mean batch inertia: 0.608369, ewa inertia: 0.735875
# Minibatch iteration 5/1300: mean batch inertia: 0.671581, ewa inertia: 0.725946
# Minibatch iteration 6/1300: mean batch inertia: 0.665549, ewa inertia: 0.716618
# Minibatch iteration 7/1300: mean batch inertia: 0.723022, ewa inertia: 0.717607
# Minibatch iteration 8/1300: mean batch inertia: 0.706830, ewa inertia: 0.715943
# Minibatch iteration 9/1300: mean batch inertia: 0.812938, ewa inertia: 0.730923
# Minibatch iteration 10/1300: mean batch inertia: 0.562446, ewa inertia: 0.704903
# Minibatch iteration 11/1300: mean batch inertia: 0.751011, ewa inertia: 0.712024
# Minibatch iteration 12/1300: mean batch inertia: 0.858585, ewa inertia: 0.734659
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch iteration 13/1300: mean batch inertia: 0.627207, ewa inertia: 0.718064
# Minibatch iteration 14/1300: mean batch inertia: 0.492227, ewa inertia: 0.683186
# Minibatch iteration 15/1300: mean batch inertia: 0.862732, ewa inertia: 0.710915
# Minibatch iteration 16/1300: mean batch inertia: 0.658200, ewa inertia: 0.702773
# Minibatch iteration 17/1300: mean batch inertia: 0.516571, ewa inertia: 0.674016
# Minibatch iteration 18/1300: mean batch inertia: 0.883435, ewa inertia: 0.706359
# Minibatch iteration 19/1300: mean batch inertia: 0.571619, ewa inertia: 0.685550
# Minibatch iteration 20/1300: mean batch inertia: 0.604016, ewa inertia: 0.672958
# Minibatch iteration 21/1300: mean batch inertia: 0.603344, ewa inertia: 0.662207
# Minibatch iteration 22/1300: mean batch inertia: 0.924792, ewa inertia: 0.702760
# Minibatch iteration 23/1300: mean batch inertia: 0.774876, ewa inertia: 0.713898
# Minibatch iteration 24/1300: mean batch inertia: 0.492537, ewa inertia: 0.679711
# Minibatch iteration 25/1300: mean batch inertia: 0.603297, ewa inertia: 0.667909
# Minibatch iteration 26/1300: mean batch inertia: 0.906137, ewa inertia: 0.704701
# Minibatch iteration 27/1300: mean batch inertia: 0.634580, ewa inertia: 0.693872
# Minibatch iteration 28/1300: mean batch inertia: 0.692611, ewa inertia: 0.693677
# Minibatch iteration 29/1300: mean batch inertia: 0.885465, ewa inertia: 0.723297
# Minibatch iteration 30/1300: mean batch inertia: 0.943342, ewa inertia: 0.757281
# Minibatch iteration 31/1300: mean batch inertia: 0.651848, ewa inertia: 0.740998
# Converged (lack of improvement in inertia) at iteration 31/1300
# Computing label assignment and total inertia
